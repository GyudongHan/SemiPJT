# %%
import pandas as pd
DATA_PATH = '/Users/kimsinwoo/Desktop/multicampus/Project/상권 raw data'
df = pd.read_csv(DATA_PATH + '/1차병합본.csv')

# %%
df
# Out:
#      기준_년_코드  기준_분기_코드    상권_코드  점포수  시간대_00~06_매출_금액_평균  시간대_06~11_매출_금액_평균  \
# 0       2020         1  2110949    6       125163.150183       217164.879121
# 1       2020         1  2110951    3        94688.223443        66467.593407
# 2       2020         1  2110952    3       177736.461538       127178.919414
# 3       2020         1  2110954    3        34587.754579        56082.139194
# 4       2020         1  2110955   30       221061.483150       145577.448352
# ..       ...       ...      ...  ...                 ...                 ...
# 909     2022         4  2110994    3        99866.931159       247191.909420
# 910     2022         4  2120210   39       303125.014214       647668.856466
# 911     2022         4  2120188   16       101724.461957       382494.941576
# 912     2022         4  2120186   15       155169.260145       270461.512319
# 913     2022         4  2120198   19       233324.990275       310145.333524
#
#      시간대_11~14_매출_금액_평균  시간대_14~17_매출_금액_평균  시간대_17~21_매출_금액_평균  \
# 0         256343.263736       217222.536630       304378.824176
# 1          80462.010989        87369.399267       188897.897436
# 2         105252.366300       103031.025641       217967.512821
# 3          74176.186813        83521.205128       138064.706960
# 4         110301.369963       137054.142125       316572.729304
# ..                  ...                 ...                 ...
# 909       194047.293478       154291.710145       302690.601449
# 910       560624.327202       442103.921962       769798.139353
# 911       316498.131114       317926.020380       468586.175951
# 912       252058.405797       247267.857971       366435.877536
# 913       302209.301487       264339.036613       476583.396453
#
#      시간대_21~24_매출_금액_평균  ...  월요일_생활인구_수  화요일_생활인구_수  수요일_생활인구_수  목요일_생활인구_수  \
# 0         222872.315018  ...       57612       59407       58948       59700
# 1         155364.446886  ...       85107       89345       88383       89759
# 2         173673.849817  ...       34098       34125       34124       34019
# 3          89737.908425  ...       75635       77314       77420       80311
# 4         240127.590110  ...      415057      418275      411498      411538
# ..                  ...  ...         ...         ...         ...         ...
# 909       201683.597826  ...       64924       65254       64715       65081
# 910       468795.999164  ...      737877      814711      816649      818883
# 911       244665.799592  ...      272225      297457      292505      295484
# 912       259723.915942  ...      314195      338030      340729      343466
# 913       323714.925057  ...      287395      307553      305851      303590
#
#      금요일_생활인구_수  토요일_생활인구_수  일요일_생활인구_수  엑스좌표_값  와이좌표_값  시군구_코드
# 0         60271       52877       47711  201717  446819   11680
# 1         89112       74083       66223  202246  446821   11680
# 2         33613       32730       33196  202328  445762   11680
# 3         84004       82246       63536  202535  444783   11680
# 4        408607      386684      388001  202593  445514   11680
# ..          ...         ...         ...     ...     ...     ...
# 909       63954       60895       57580  205441  442634   11680
# 910      786553      553938      475110  204334  445014   11680
# 911      305916      259018      212265  202455  447347   11680
# 912      355283      319185      267477  201997  446820   11680
# 913      289938      219934      218803  203312  443991   11680
#
# [914 rows x 40 columns]

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns 


rc('font', family='AppleGothic') 
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize = (20,15))
sns.heatmap(data = df.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')
plt.show()

# %%
df.isna().sum()
# Out:
# 기준_년_코드                0
# 기준_분기_코드               0
# 상권_코드                  0
# 점포수                    0
# 시간대_00~06_매출_금액_평균     0
# 시간대_06~11_매출_금액_평균     0
# 시간대_11~14_매출_금액_평균     0
# 시간대_14~17_매출_금액_평균     0
# 시간대_17~21_매출_금액_평균     0
# 시간대_21~24_매출_금액_평균     0
# 총 상주인구 수              12
# 총 가구 수                12
# 아파트 가구 수              12
# 비아파트 가구 수             12
# 총_직장인구_수               0
# 아파트_단지_수              68
# 아파트_가격_1_억_미만_세대_수    68
# 아파트_가격_1_억_세대_수       68
# 아파트_가격_2_억_세대_수       68
# 아파트_가격_3_억_세대_수       68
# 아파트_가격_4_억_세대_수       68
# 아파트_가격_5_억_세대_수       68
# 아파트_가격_6_억_이상_세대_수    68
# 총_생활인구_수               0
# 시간대_1_생활인구_수           0
# 시간대_2_생활인구_수           0
# 시간대_3_생활인구_수           0
# 시간대_4_생활인구_수           0
# 시간대_5_생활인구_수           0
# 시간대_6_생활인구_수           0
# 월요일_생활인구_수             0
# 화요일_생활인구_수             0
# 수요일_생활인구_수             0
# 목요일_생활인구_수             0
# 금요일_생활인구_수             0
# 토요일_생활인구_수             0
# 일요일_생활인구_수             0
# 엑스좌표_값                 0
# 와이좌표_값                 0
# 시군구_코드                 0
# dtype: int64
